# %%
#%run ./data_extraction.ipynb
# %run bigbluedataset.ipynb
# %run exploration.ipynb

# %%
initial_dataset = import_data()

# %%
processed_dataset = preprocessing(initial_dataset)

# %%
counts(processed_dataset, 'Department')

# %%
salary_pie(processed_dataset, 'Monthly_Salary', 'Department')

# %%
salary_bars(processed_dataset, 'Monthly_Salary', 'City')

# %%
stacked_bar_100(processed_dataset, 'Gender', 'Education_Level')

# %%
scatterplot(processed_dataset, 'Experience_Years', 'Monthly_Salary', 'Department')
